# %%
"""
Contains the code for baseline DecisionTreeClassifier on SSE
"""

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import tree
from SSE import train_data_X, train_data_Y, test_data_X, test_data_Y, feature_names
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\psvka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\psvka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\psvka\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# 100%|██████████| 200000/200000 [05:49<00:00, 572.65it/s]

# %%
trainx, trainy, testx, testy, fn = train_data_X, train_data_Y, test_data_X, test_data_Y, feature_names

# %%
fn
# Out:
# ['np_count',
#  'vp_count',
#  'pp_count',
#  'sbar_count',
#  'np_ratio',
#  'vp_ratio',
#  'pp_ratio',
#  'phrase_length_ratios_VP',
#  'phrase_length_ratios_NP',
#  'phrase_length_ratios_PP',
#  'avg_NP_len',
#  'avg_VP_len',
#  'avg_PP_len',
#  'rpnv']

# %%
baseline_model = DecisionTreeClassifier(max_depth=5)

baseline_model.fit(train_data_X, train_data_Y)

baseline_model.score(train_data_X, train_data_Y)

preds = baseline_model.predict(test_data_X)
plt.figure(figsize=(15,15))

print(classification_report(preds, test_data_Y))
tree.plot_tree(baseline_model, feature_names=feature_names, class_names=['True', 'False'], filled=True, fontsize=10)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.72      0.73      0.73     29868
#         True       0.73      0.72      0.73     30132
#
#     accuracy                           0.73     60000
#    macro avg       0.73      0.73      0.73     60000
# weighted avg       0.73      0.73      0.73     60000
